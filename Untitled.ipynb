# %%
import spacy
import pytextrank

# example text
text = """Compatibility of systems of linear constraints over the set of natural numbers.
Criteria of compatibility of a system of linear Diophantine equations, strict inequations,
and nonstrict inequations are considered. Upper bounds for components of a minimal set of
solutions and algorithms of construction of minimal generating sets of solutions for all types
of systems are given. These criteria and the corresponding algorithms for constructing a minimal
supporting set of solutions can be used in solving all the considered types systems and systems of mixed types."""

# load a spaCy model, depending on language, scale, etc.
nlp = spacy.load("en_core_web_sm")
# add PyTextRank to the spaCy pipeline
nlp.add_pipe("textrank")

doc = nlp(text)
# examine the top-ranked phrases in the document
for phrase in doc._.phrases:
    print(phrase.text)
    print(phrase.rank, phrase.count)
    print(phrase.chunks)
# Out:
# mixed types
# 0.16913297519493323 1
# [mixed types]
# minimal generating sets
# 0.15718190861803338 1
# [minimal generating sets]
# systems
# 0.15706451042108485 3
# [systems, systems, systems]
# nonstrict inequations
# 0.14754717053336916 1
# [nonstrict inequations]
# strict inequations
# 0.13924933655642574 1
# [strict inequations]
# natural numbers
# 0.11617695958368299 1
# [natural numbers]
# linear Diophantine equations
# 0.11604222593721583 1
# [linear Diophantine equations]
# solutions
# 0.11339988816808184 3
# [solutions, solutions, solutions]
# linear constraints
# 0.10253057199702881 1
# [linear constraints]
# all the considered types systems
# 0.08793429413519571 1
# [all the considered types systems]
# a minimal set
# 0.08280312704561263 1
# [a minimal set]
# algorithms
# 0.08242870171999762 1
# [algorithms]
# construction
# 0.07382060769521386 1
# [construction]
# a system
# 0.0725449898974001 1
# [a system]
# Diophantine
# 0.07111006100211886 1
# [Diophantine]
# all types
# 0.06977165930609519 1
# [all types]
# a minimal
# supporting set
# 0.06824144622770673 1
# [a minimal
# supporting set]
# Upper bounds
# 0.06353124347005579 1
# [Upper bounds]
# the set
# 0.05953585992764829 1
# [the set]
# components
# 0.057229483887326044 1
# [components]
# Compatibility
# 0.05051834579518455 1
# [Compatibility]
# compatibility
# 0.05051834579518455 1
# [compatibility]
# the corresponding algorithms
# 0.0483388925429777 1
# [the corresponding algorithms]
# Criteria
# 0.044594203626436756 1
# [Criteria]
# These criteria
# 0.0205971803744162 1
# [These criteria]

# %%
#Echemos un vistazo a esta canalización ahora...
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'textrank']

# %%
# Podemos examinar la spaCytubería con mucho más detalle...
nlp.analyze_pipes(pretty=True)
# Out:
# ============================= Pipeline Overview =============================
#
# #   Component         Assigns               Requires   Scores             Retokenizes
# -   ---------------   -------------------   --------   ----------------   -----------
# 0   tok2vec           doc.tensor                                          False
#
# 1   tagger            token.tag                        tag_acc            False
#
# 2   parser            token.dep                        dep_uas            False
#                       token.head                       dep_las
#                       token.is_sent_start              dep_las_per_type
#                       doc.sents                        sents_p
#                                                        sents_r
#                                                        sents_f
#
# 3   attribute_ruler                                                       False
#
# 4   lemmatizer        token.lemma                      lemma_acc          False
#
# 5   ner               doc.ents                         ents_f             False
#                       token.ent_iob                    ents_p
#                       token.ent_type                   ents_r
#                                                        ents_per_type
#
# 6   textrank                                                              False
#
# ✔ No problems found.
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
#    'retokenizes': False},
#   'textrank': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False}},
#  'problems': {'tok2vec': [],
#   'tagger': [],
#   'parser': [],
#   'attribute_ruler': [],
#   'lemmatizer': [],
#   'ner': [],
#   'textrank': []},
#  'attrs': {'token.head': {'assigns': ['parser'], 'requires': []},
#   'token.lemma': {'assigns': ['lemmatizer'], 'requires': []},
#   'doc.ents': {'assigns': ['ner'], 'requires': []},
#   'token.ent_type': {'assigns': ['ner'], 'requires': []},
#   'token.tag': {'assigns': ['tagger'], 'requires': []},
#   'token.is_sent_start': {'assigns': ['parser'], 'requires': []},
#   'doc.tensor': {'assigns': ['tok2vec'], 'requires': []},
#   'token.dep': {'assigns': ['parser'], 'requires': []},
#   'token.ent_iob': {'assigns': ['ner'], 'requires': []},
#   'doc.sents': {'assigns': ['parser'], 'requires': []}}}

# %%
#A continuación, carguemos texto de un documento desde mi equipo :
from icecream import ic
import pathlib

text = pathlib.Path("C:/Users/Dellç/Desktop/Informatica.txt").read_text()
text
# Out:
# 'La InformÃ¡tica es la rama de la IngenierÃ\xada que estudia el hardware, las redes de datos y el software necesarios para tratar informaciÃ³n de forma automÃ¡tica. Aunque pueda parecerte una definiciÃ³n muy abstracta, estamos seguros de que sabes mucho mÃ¡s de InformÃ¡tica de lo que crees. Y si no, sigue leyendo un poco mÃ¡s.\nSeguro que te suena quÃ© es el hardware. Y si no te suena, seguro que has utilizado hardware en muchas ocasiones sin saber que se llama asÃ\xad. El hardware son los ordenadores de sobremesa, los portÃ¡tiles, los tablets, los telÃ©fonos mÃ³viles, las impresoras, las consolas de videojuegos, los lectores de DVDs, los reproductores de mÃºsica, etcÃ©tera. Â¿A que sÃ\xad que sabÃ\xadas quÃ© es el hardware? Lo que quizÃ¡ no sabÃ\xadas es que estos aparatos estÃ¡n formados internamente por componentes electrÃ³nicos a los que tambiÃ©n se les llama hardware: Â¿te suenan el microprocesador, las tarjetas de memoria, las tarjetas grÃ¡ficas, los discos duros o los acelerÃ³metros? Â¡Seguro que sÃ\xad! Y aunque no los veas, hay miles de dispositivos llamados sistemas empotrados que ayudan a los coches a tomar mejor las curvas, a los aviones a volar en las peores condiciones atmosfÃ©ricas o a los semÃ¡foros a controlar el trÃ¡fico de forma inteligente; tambiÃ©n son hardware y tambiÃ©n se estudian en InformÃ¡tica.'

# %%
#Longitud del texto cargado
doc = nlp(text)
len(doc)
# Out:
# 258

# %%
#acceder al componente PyTextRank dentro de la spaCycanalización 
#usarlo para obtener más información para el procesamiento posterior del documento
tr = doc._.textrank
ic(tr.elapsed_time);
# Out:
# ic| tr.elapsed_time: 0.0

# %%
for phrase in doc._.phrases:
    ic(phrase.rank, phrase.count, phrase.text)
    ic(phrase.chunks)
# Out:
# ic| phrase.rank: 0.12084959385708814
#     phrase.count: 2
#     phrase.text: 'los lectores de DVDs'
# ic| phrase.chunks: [los lectores de DVDs, los lectores de DVDs]
# ic| phrase.rank: 0.12084933746609591
#     phrase.count: 1
#     phrase.text: 'los telÃ©fonos mÃ³viles'
# ic| phrase.chunks: [los telÃ©fonos mÃ³viles]
# ic| phrase.rank: 0.12039557687926086
#     phrase.count: 1
#     phrase.text: 'los reproductores de mÃºsica'
# ic| phrase.chunks: [los reproductores de mÃºsica]
# ic| phrase.rank: 0.12026071863463483
#     phrase.count: 1
#     phrase.text: 'los ordenadores de sobremesa'
# ic| phrase.chunks: [los ordenadores de sobremesa]
# ic| phrase.rank: 0.12012628961194063
#     phrase.count: 6
#     phrase.text: 'los'
# ic| phrase.chunks: [los, los, los, los, los, los]
# ic| phrase.rank: 0.1198230470372881
#     phrase.count: 1
#     phrase.text: 'los semÃ¡foros'
# ic| phrase.chunks: [los semÃ¡foros]
# ic| phrase.rank: 0.11892416238723205
#     phrase.count: 2
#     phrase.text: 'los portÃ¡tiles'
# ic| phrase.chunks: [los portÃ¡tiles, los portÃ¡tiles]
# ic| phrase.rank: 0.11874989703705664
#     phrase.count: 2
#     phrase.text: 'los tablets'
# ic| phrase.chunks: [los tablets, los tablets]
# ic| phrase.rank: 0.1187005583210454
#     phrase.count: 1
#     phrase.text: 'los telÃ'
# ic| phrase.chunks: [los telÃ]
# ic| phrase.rank: 0.11830363271030589
#     phrase.count: 1
#     phrase.text: 'los discos duros'
# ic| phrase.chunks: [los discos duros]
# ic| phrase.rank: 0.11650908795341837
#     phrase.count: 1
#     phrase.text: 'los veas'
# ic| phrase.chunks: [los veas]
# ic| phrase.rank: 0.1075630260202677
#     phrase.count: 1
#     phrase.text: 'las tarjetas'
# ic| phrase.chunks: [las tarjetas]
# ic| phrase.rank: 0.10547511913070329
#     phrase.count: 5
#     phrase.text: 'el hardware'
# ic| phrase.chunks: [el hardware, el hardware, el hardware, el hardware, el hardware]
# ic| phrase.rank: 0.10523505813946735
#     phrase.count: 1
#     phrase.text: 'las tarjetas grÃ¡ficas'
# ic| phrase.chunks: [las tarjetas grÃ¡ficas]
# ic| phrase.rank: 0.1006986795333456
#     phrase.count: 2
#     phrase.text: 'las impresoras'
# ic| phrase.chunks: [las impresoras, las impresoras]
# ic| phrase.rank: 0.10065151534967894
#     phrase.count: 1
#     phrase.text: 'las curvas'
# ic| phrase.chunks: [las curvas]
# ic| phrase.rank: 0.09950912249026769
#     phrase.count: 1
#     phrase.text: 'o los acelerÃ³metros? Â¡Seguro'
# ic| phrase.chunks: [o los acelerÃ³metros? Â¡Seguro]
# ic| phrase.rank: 0.09892653076592706
#     phrase.count: 1
#     phrase.text: 'las'
# ic| phrase.chunks: [las]
# ic| phrase.rank: 0.09560238149621189
#     phrase.count: 1
#     phrase.text: 'Â¿A que sÃ\xad que'
# ic| phrase.chunks: [Â¿A que sÃ­ que]
# ic| phrase.rank: 0.09228258641814453
#     phrase.count: 1
#     phrase.text: 'el microprocesador'
# ic| phrase.chunks: [el microprocesador]
# ic| phrase.rank: 0.09067061900748781
#     phrase.count: 1
#     phrase.text: '©tera'
# ic| phrase.chunks: [©tera]
# ic| phrase.rank: 0.08611014589732956
#     phrase.count: 4
#     phrase.text: '©'
# ic| phrase.chunks: [©, ©, ©, ©]
# ic| phrase.rank: 0.08535007716884818
#     phrase.count: 1
#     phrase.text: 'saber que'
# ic| phrase.chunks: [saber que]
# ic| phrase.rank: 0.08450316365698692
#     phrase.count: 1
#     phrase.text: 'que estos'
# ic| phrase.chunks: [que estos]
# ic| phrase.rank: 0.0844533447436415
#     phrase.count: 1
#     phrase.text: 'que sÃ\xad'
# ic| phrase.chunks: [que sÃ­]
# ic| phrase.rank: 0.08444139165354543
#     phrase.count: 1
#     phrase.text: 'que ayudan'
# ic| phrase.chunks: [que ayudan]
# ic| phrase.rank: 0.08408857864292672
#     phrase.count: 1
#     phrase.text: 'la rama de la IngenierÃ\xada'
# ic| phrase.chunks: [la rama de la IngenierÃ­a]
# ic| phrase.rank: 0.08182322933758307
#     phrase.count: 1
#     phrase.text: 'rama de la IngenierÃ\xada'
# ic| phrase.chunks: [rama de la IngenierÃ­a]
# ic| phrase.rank: 0.08147134653314846
#     phrase.count: 1
#     phrase.text: 'seguro que'
# ic| phrase.chunks: [seguro que]
# ic| phrase.rank: 0.08063264030673215
#     phrase.count: 1
#     phrase.text: 'y tambiÃ'
# ic| phrase.chunks: [y tambiÃ]
# ic| phrase.rank: 0.0773098836574149
#     phrase.count: 1
#     phrase.text: 'de mÃºsica'
# ic| phrase.chunks: [de mÃºsica]
# ic| phrase.rank: 0.07535108603041515
#     phrase.count: 1
#     phrase.text: 'utilizado hardware'
# ic| phrase.chunks: [utilizado hardware]
# ic| phrase.rank: 0.07248518905185673
#     phrase.count: 1
#     phrase.text: 'a los que'
# ic| phrase.chunks: [a los que]
# ic| phrase.rank: 0.06993827231494723
#     phrase.count: 1
#     phrase.text: 'El hardware son'
# ic| phrase.chunks: [El hardware son]
# ic| phrase.rank: 0.06354576682687581
#     phrase.count: 1
#     phrase.text: 'a los semÃ¡foros'
# ic| phrase.chunks: [a los semÃ¡foros]
# ic| phrase.rank: 0.06350790375796533
#     phrase.count: 2
#     phrase.text: 'llama'
# ic| phrase.chunks: [llama, llama]
# ic| phrase.rank: 0.062470085636599434
#     phrase.count: 1
#     phrase.text: 'son hardware'
# ic| phrase.chunks: [son hardware]
# ic| phrase.rank: 0.06234032816118135
#     phrase.count: 2
#     phrase.text: 'las tarjetas de memoria'
# ic| phrase.chunks: [las tarjetas de memoria, las tarjetas de memoria]
# ic| phrase.rank: 0.061788274621291515
#     phrase.count: 1
#     phrase.text: 'no los veas'
# ic| phrase.chunks: [no los veas]
# ic| phrase.rank: 0.06132372311671966
#     phrase.count: 1
#     phrase.text: 'discos duros'
# ic| phrase.chunks: [discos duros]
# ic| phrase.rank: 0.061197927970589656
#     phrase.count: 1
#     phrase.text: 'a tomar mejor las curvas'
# ic| phrase.chunks: [a tomar mejor las curvas]
# ic| phrase.rank: 0.058476698815265314
#     phrase.count: 2
#     phrase.text: 'las consolas de videojuegos'
# ic| phrase.chunks: [las consolas de videojuegos, las consolas de videojuegos]
# ic| phrase.rank: 0.05583508689063753
#     phrase.count: 1
#     phrase.text: 'atmosfÃ©'
# ic| phrase.chunks: [atmosfÃ©]
# ic| phrase.rank: 0.0554839565153639
#     phrase.count: 2
#     phrase.text: 'a los'
# ic| phrase.chunks: [a los, a los]
# ic| phrase.rank: 0.05407517608474791
#     phrase.count: 1
#     phrase.text: 'mÃ¡s de InformÃ¡tica de lo que crees'
# ic| phrase.chunks: [mÃ¡s de InformÃ¡tica de lo que crees]
# ic| phrase.rank: 0.05231320477893342
#     phrase.count: 1
#     phrase.text: 'muchas ocasiones'
# ic| phrase.chunks: [muchas ocasiones]
# ic| phrase.rank: 0.051361724258287896
#     phrase.count: 1
#     phrase.text: 'Lo que quizÃ¡ no sabÃ\xadas'
# ic| phrase.chunks: [Lo que quizÃ¡ no sabÃ­as]
# ic| phrase.rank: 0.04901447670821203
#     phrase.count: 1
#     phrase.text: 'Â¿te'
# ic| phrase.chunks: [Â¿te]
# ic| phrase.rank: 0.04796324969423602
#     phrase.count: 1
#     phrase.text: '
#                   Seguro que te suena'
# ic| phrase.chunks: [
#                    Seguro que te suena]
# ic| phrase.rank: 0.04673006659457209
#     phrase.count: 1
#     phrase.text: 'a controlar el trÃ¡fico de forma inteligente'
# ic| phrase.chunks: [a controlar el trÃ¡fico de forma inteligente]
# ic| phrase.rank: 0.044607111402217355
#     phrase.count: 1
#     phrase.text: 'de que sabes'
# ic| phrase.chunks: [de que sabes]
# ic| phrase.rank: 0.04396450931453965
#     phrase.count: 1
#     phrase.text: 'electrÃ³nicos'
# ic| phrase.chunks: [electrÃ³nicos]
# ic| phrase.rank: 0.043684519220819604
#     phrase.count: 1
#     phrase.text: 'muy abstracta'
# ic| phrase.chunks: [muy abstracta]
# ic| phrase.rank: 0.043497928047940226
#     phrase.count: 1
#     phrase.text: 'estÃ¡n formados internamente por componentes'
# ic| phrase.chunks: [estÃ¡n formados internamente por componentes]
# ic| phrase.rank: 0.04288429358407243
#     phrase.count: 2
#     phrase.text: 'ricas'
# ic| phrase.chunks: [ricas, ricas]
# ic| phrase.rank: 0.041831325718370234
#     phrase.count: 1
#     phrase.text: 'grÃ¡ficas'
# ic| phrase.chunks: [grÃ¡ficas]
# ic| phrase.rank: 0.041014117844983794
#     phrase.count: 1
#     phrase.text: 'condiciones'
# ic| phrase.chunks: [condiciones]
# ic| phrase.rank: 0.03980226820137856
#     phrase.count: 1
#     phrase.text: 'etcÃ'
# ic| phrase.chunks: [etcÃ]
# ic| phrase.rank: 0.03946198301652043
#     phrase.count: 1
#     phrase.text: 'mÃ³viles'
# ic| phrase.chunks: [mÃ³viles]
# ic| phrase.rank: 0.038980896733812505
#     phrase.count: 1
#     phrase.text: 'n se les llama hardware'
# ic| phrase.chunks: [n se les llama hardware]
# ic| phrase.rank: 0.037888746757237475
#     phrase.count: 1
#     phrase.text: 'ayudan'
# ic| phrase.chunks: [ayudan]
# ic| phrase.rank: 0.037771102199313324
#     phrase.count: 1
#     phrase.text: 'Aunque pueda parecerte una'
# ic| phrase.chunks: [Aunque pueda parecerte una]
# ic| phrase.rank: 0.03508413039924136
#     phrase.count: 1
#     phrase.text: 'estamos'
# ic| phrase.chunks: [estamos]
# ic| phrase.rank: 0.03334302162271478
#     phrase.count: 2
#     phrase.text: 'quÃ'
# ic| phrase.chunks: [quÃ, quÃ]
# ic| phrase.rank: 0.029684891318027366
#     phrase.count: 1
#     phrase.text: 'seguro'
# ic| phrase.chunks: [seguro]
# ic| phrase.rank: 0.028606448553700946
#     phrase.count: 1
#     phrase.text: 'un'
# ic| phrase.chunks: [un]
# ic| phrase.rank: 0.02720005179766699
#     phrase.count: 1
#     phrase.text: 'informaciÃ³n de forma automÃ¡tica'
# ic| phrase.chunks: [informaciÃ³n de forma automÃ¡tica]
# ic| phrase.rank: 0.02620434031437227
#     phrase.count: 1
#     phrase.text: 'Y aunque'
# ic| phrase.chunks: [Y aunque]
# ic| phrase.rank: 0.019774743540194373
#     phrase.count: 1
#     phrase.text: 'de forma automÃ¡tica'
# ic| phrase.chunks: [de forma automÃ¡tica]
# ic| phrase.rank: 0.01967896744457015
#     phrase.count: 1
#     phrase.text: 'se estudian'
# ic| phrase.chunks: [se estudian]
# ic| phrase.rank: 0.019205045752720588
#     phrase.count: 1
#     phrase.text: 'El'
# ic| phrase.chunks: [El]
# ic| phrase.rank: 0.019205045752720588
#     phrase.count: 1
#     phrase.text: 'Lo'
# ic| phrase.chunks: [Lo]
# ic| phrase.rank: 0.019205045752720588
#     phrase.count: 1
#     phrase.text: 'Â¿A'
# ic| phrase.chunks: [Â¿A]
# ic| phrase.rank: 0.018391273369493203
#     phrase.count: 1
#     phrase.text: 'a volar'
# ic| phrase.chunks: [a volar]
# ic| phrase.rank: 0.017919392854541118
#     phrase.count: 1
#     phrase.text: 'Y si no te suena'
# ic| phrase.chunks: [Y si no te suena]

# %%
text = pathlib.Path("C:/Users/Dellç/Desktop/Informatica.txt").read_text()
doc = nlp(text)

for phrase in doc._.phrases[:10]:
    ic(phrase)
# Out:
# ic| phrase: Phrase(text='los lectores de DVDs',
#                    chunks=[los lectores de DVDs, los lectores de DVDs],
#                    count=2,
#                    rank=0.12084959385708814)
# ic| phrase: Phrase(text='los telÃ©fonos mÃ³viles',
#                    chunks=[los telÃ©fonos mÃ³viles],
#                    count=1,
#                    rank=0.12084933746609591)
# ic| phrase: Phrase(text='los reproductores de mÃºsica',
#                    chunks=[los reproductores de mÃºsica],
#                    count=1,
#                    rank=0.12039557687926086)
# ic| phrase: Phrase(text='los ordenadores de sobremesa',
#                    chunks=[los ordenadores de sobremesa],
#                    count=1,
#                    rank=0.12026071863463483)
# ic| phrase: Phrase(text='los',
#                    chunks=[los, los, los, los, los, los],
#                    count=6,
#                    rank=0.12012628961194063)
# ic| phrase: Phrase(text='los semÃ¡foros',
#                    chunks=[los semÃ¡foros],
#                    count=1,
#                    rank=0.1198230470372881)
# ic| phrase: Phrase(text='los portÃ¡tiles',
#                    chunks=[los portÃ¡tiles, los portÃ¡tiles],
#                    count=2,
#                    rank=0.11892416238723205)
# ic| phrase: Phrase(text='los tablets',
#                    chunks=[los tablets, los tablets],
#                    count=2,
#                    rank=0.11874989703705664)
# ic| phrase: Phrase(text='los telÃ', chunks=[los telÃ], count=1, rank=0.1187005583210454)
# ic| phrase: Phrase(text='los discos duros',
#                    chunks=[los discos duros],
#                    count=1,
#                    rank=0.11830363271030589)
